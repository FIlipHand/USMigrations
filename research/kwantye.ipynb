# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('../data/better_processed/wszystko.csv', sep=';')
data = data.ffill()
data = data.bfill()
data.head()
# Out:
#    FIPS code    State          County  Some college (1-3 years), 1970  \
# 0       1001  Alabama  Autauga County                           933.0
# 1       1003  Alabama  Baldwin County                          2334.0
# 2       1005  Alabama  Barbour County                           581.0
# 3       1007  Alabama     Bibb County                           238.0
# 4       1009  Alabama   Blount County                           626.0
#
#    Four years of college or higher, 1970  \
# 0                                  767.0
# 1                                 2038.0
# 2                                  861.0
# 3                                  302.0
# 4                                  404.0
#
#    Percent of adults with less than a high school diploma, 1970  \
# 0                                               54.8
# 1                                               59.4
# 2                                               68.8
# 3                                               73.1
# ...

# %%
only_data = data.iloc[:, 3:-1]
scaler = StandardScaler()
only_data_scl = pd.DataFrame(scaler.fit_transform(only_data), columns=only_data.columns)

# %%
column_means = only_data_scl.mean()
deviation_data = (only_data_scl - column_means) / only_data_scl.std()

# %%
results = deviation_data.filter(like='2020')

results['NPOPCHG2022'] = data['NPOPCHG2022']
results = results.sort_values(by='NPOPCHG2022').tail(15)

results['County'] = data['County']
results['State'] = data['State']
cols = ['State', 'County']
cols.extend(results.columns[:-2])
results = results[cols]
results
# Out:
# C:\Users\Filif\AppData\Local\Temp\ipykernel_10312\1421834915.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results['NPOPCHG2022'] = data['NPOPCHG2022']
#                State               County  \
# 1782  North Carolina          Wake County
# 322          Florida         Pasco County
# 2321           Texas        Harris County
# 2262           Texas         Bexar County
# 299          Florida  Hillsborough County
# 181       California     Riverside County
# 1560          Nevada         Clark County
# 2368           Texas    Montgomery County
# 306          Florida           Lee County
# 324          Florida          Polk County
# 2420           Texas    Williamson County
# 2304           Texas     Fort Bend County
# ...

# %%
najlepsze = results.mean()
# Out:
# C:\Users\Filif\AppData\Local\Temp\ipykernel_10312\3843923530.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   najlepsze = results.mean()
